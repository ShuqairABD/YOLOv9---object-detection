# %% [markdown]
# <a href="https://colab.research.google.com/github/ShuqairABD/YOLOv9---object-detection/blob/main/YOLOv9_object_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Mar  1 18:09:10 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# **Клонирование репозитория**

# %%
# Клонирование репозитория с YOLOv9
# !git clone https://github.com/SkalskiP/yolov9.git

# Переход в каталог yolov9
# %cd yolov9

# Установка зависимостей из requirements.txt
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 147, done.
# remote: Total 147 (delta 0), reused 0 (delta 0), pack-reused 147
# Receiving objects: 100% (147/147), 607.53 KiB | 3.92 MiB/s, done.
# Resolving deltas: 100% (58/58), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 13.7 MB/s eta 0:00:00

# %%
# !pip install -q roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 15.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.5 MB/s eta 0:00:00

# %%
import roboflow

from IPython.display import Image

# %%
# Создание директории для хранения весовых файлов модели
# !mkdir -p {HOME}/weights

# %%
# Вывод списка файлов и директорий в директории для хранения весовых файлов модели
# !ls -la {HOME}/weights
# Out:
# total 402440
# drwxr-xr-x 2 root root      4096 Mar  1 18:09 .
# drwxr-xr-x 1 root root      4096 Mar  1 18:09 ..
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %% [markdown]
# **image data!**

# %%
# Создание директории для хранения данных
# !mkdir -p {HOME}/data

# %%
SOURCE_IMAGE_PATH = f"{HOME}/content/data/999.png"

# %% [markdown]
#  **Обнаружение с предварительно обученной моделью COCO**. **gelan-c**

# %%
# Запуск скрипта detect.py с использованием указанных весов модели и источника изображения

# !python detect.py --weights {HOME}/weights/gelan-c.pt --conf 0.1 --source {HOME}/data/999.png --device 0
# Out:
# detect: weights=['/content/weights/gelan-c.pt'], source=/content/data/999.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 467 layers, 25472640 parameters, 0 gradients, 102.8 GFLOPs
# image 1/1 /content/data/999.png: 384x640 6 persons, 5 cars, 1 truck, 2 ties, 146.8ms
# Speed: 0.5ms pre-process, 146.8ms inference, 649.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
Image(filename=f"{HOME}/yolov9/runs/detect/exp/999.png", width=600)

# %% [markdown]
# **Обнаружение с YOLOv9-e**

# %%
# Запускаем скрипт detect.py с указанием весов, порога уверенности, исходного изображения и устройства

# !python detect.py --weights {HOME}/weights/yolov9-e.pt --conf 0.1 --source {HOME}/data/999.png --device 0
# Out:
# detect: weights=['/content/weights/yolov9-e.pt'], source=/content/data/999.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 1119 layers, 69470144 parameters, 0 gradients, 244.0 GFLOPs
# image 1/1 /content/data/999.png: 384x640 6 persons, 4 cars, 1 truck, 177.9ms
# Speed: 0.5ms pre-process, 177.9ms inference, 574.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
Image(filename=f"{HOME}/yolov9/runs/detect/exp2/999.png", width=600)
